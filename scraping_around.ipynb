# %%
from bs4 import BeautifulSoup
import requests
import csv
import math 
math.ceil(346/100)

def scrape_all_regions(link):
    soup = make_soup(link)
    items = soup.find_all('a',class_ = "regionLink")
    links = [link.get('href') for link in items]

    return links



def find_number_of_trail_pages(region):
    trails =  region + 'trails/'
    soup = make_soup(trails)
    try:
        num_trails = int(soup.find('div',class_="resultTotal").strong.text)
        num_pages = range(1,math.ceil(num_trails/100)+1)
    except:
        num_pages = 'no_trails'
    return num_pages


def scrape_region(region):
    result_pages = find_number_of_trail_pages(region)
    if result_pages == 'no trails':
        trail_list = ['no_trails']
        return trail_list
    else:
        trail_list = []
        for i in result_pages:
            page = region + 'trails/?page=' + str(i)
            soup = make_soup(page)
            trail_rows = soup.find_all('a',{'class':'green'})
            trail_list.extend([link.get('href') for link in trail_rows])
            print('scraped',str(i*100),'trails!')
    return trail_list
        

def write_to_csvs(region):
    trails = scrape_region(region)
    name = re.findall('\w+/+$',region)[0][:-1]
    with open(name + '_trails.csv','w') as f:
        wrtr = csv.writer(f)
        for trail in trails:   
            wrtr.writerow([trail])
    print('Finished scraping {}!'.format(name))

def main():
#     regions = scrape_all_regions('https://www.trailforks.com/trails/')
#     with open('regions.csv','w') as f:
#         write = csv.writer(f)
#         for reg in regions:
#             write.writerow([reg])

#     with open('regions.csv','r') as f:
#         regions = [reg.strip() for reg in f]
    
    for reg in regions :
        write_to_csvs(reg)

# %%
main()
# Out:
# /Users/forest.polchow/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/forest.polchow/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# Finished scraping afghanistan!
# scraped 100 trails!
# Finished scraping albania!
# scraped 100 trails!
# Finished scraping algeria!
# scraped 100 trails!
# Finished scraping andorra!
# scraped 100 trails!
# Finished scraping antarctica!
# scraped 100 trails!
# Finished scraping 10771!
# scraped 100 trails!
# ...

# %%
regions = []
with open('regions.csv','r') as f:
    for line in f:
        if ('united-states' in line) or ('canada' in line):
            print(line)
            continue
        else:
            regions.append(line.strip())
# Out:
# https://www.trailforks.com/region/canada/
#
# https://www.trailforks.com/region/united-states/

# %%
regions.index('https://www.trailforks.com/region/afghanistan/')
# Out:
# 65

# %%
regions[65:]
# Out:
# ['https://www.trailforks.com/region/afghanistan/',
#  'https://www.trailforks.com/region/albania/',
#  'https://www.trailforks.com/region/algeria/',
#  'https://www.trailforks.com/region/andorra/',
#  'https://www.trailforks.com/region/antarctica/',
#  'https://www.trailforks.com/region/antigua--barbuda-10771/',
#  'https://www.trailforks.com/region/argentina/',
#  'https://www.trailforks.com/region/armenia-11/',
#  'https://www.trailforks.com/region/aruba/',
#  'https://www.trailforks.com/region/australia/',
#  'https://www.trailforks.com/region/austria/',
#  'https://www.trailforks.com/region/azerbaijan/',
#  'https://www.trailforks.com/region/bangladesh/',
#  'https://www.trailforks.com/region/barbados/',
#  'https://www.trailforks.com/region/belgium/',
#  'https://www.trailforks.com/region/belize/',
#  'https://www.trailforks.com/region/bermuda/',
#  'https://www.trailforks.com/region/bolivia/',
#  'https://www.trailforks.com/region/bonaire/',
# ...

# %%
write_to_csvs('https://www.trailforks.com/region/louisiana/')
# Out:
# /Users/forest.polchow/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/forest.polchow/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
# Out:
# louisiana_trails.csv  scraping.py
# regions.csv           scraping_around.ipynb

# %%
import re
# re.match('\w+/+$','https://www.trailforks.com/region/utah/')
name = re.findall('\w+/+$','https://www.trailforks.com/region/utah/')[0][:-1]

# %%
# Out:
# 'utah'

# %%
utah = scrape_trails('https://www.trailforks.com/region/utah/')
# Out:
# /Users/forest.polchow/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/forest.polchow/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
len(louisiana)
# Out:
# 75

# %%
len(utah)
# Out:
# 2745

# %%
rows = soup.find_all('a',{'class':'green'})

# %%
trails = [link.get('href') for link in rows]

# %%
with open('test.csv','w') as f:
    writer = csv.writer(f)
    writer.writerows(someiterable)
# Out:
# ['https://www.trailforks.com/trails/1/',
#  'https://www.trailforks.com/trails/1-143429/',
#  'https://www.trailforks.com/trails/10-55357/',
#  'https://www.trailforks.com/trails/10-143445/',
#  'https://www.trailforks.com/trails/11-122700/',
#  'https://www.trailforks.com/trails/2-55349/',
#  'https://www.trailforks.com/trails/2-143430/',
#  'https://www.trailforks.com/trails/3-55350/',
#  'https://www.trailforks.com/trails/3-143431/',
#  'https://www.trailforks.com/trails/32-to-4-connector/',
#  'https://www.trailforks.com/trails/4-55351/',
#  'https://www.trailforks.com/trails/4-143432/',
#  'https://www.trailforks.com/trails/5-55352/',
#  'https://www.trailforks.com/trails/5-143433/',
#  'https://www.trailforks.com/trails/6-143434/',
#  'https://www.trailforks.com/trails/7-55353/',
#  'https://www.trailforks.com/trails/7-143446/',
#  'https://www.trailforks.com/trails/8/',
#  'https://www.trailforks.com/trails/8-fast-track/',
#  'https://www.trailforks.com/trails/9/',
# ...

# %%
 with open(name + '_trails.csv','w') as f:
        wrtr = csv.writer(f)
        wrtr.writerows(trails)
# Out:
# 4

# %%
regions = scrape_all_regions('https://www.trailforks.com/trails/')
# Out:
# /Users/forest.polchow/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/forest.polchow/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
with open('regions.csv','w') as f:
    write = csv.writer(f)
    for reg in regions:
        write.writerow([reg])

# %%
from sklearn.linear_model import LogisticRegression

# %%
from collections import Counter

def scrape_user_info(url):
    user_url = url + 'ridelogs/'
    soup =  make_soup(user_url)
    try:
        num_trails = int(soup.find('div',class_="resultTotal").strong.text)
        num_pages = range(1,math.ceil(num_trails/100)+1)
    except:
        return 'no_logs'
    user_list = []
    for i in num_pages:
        page = url + 'ridelogs/?page=' + str(i)
        soup = make_soup(page)
        user_profile_urls = soup.find_all(href=re.compile('profile'))
        user_list.extend([user.text for user in user_profile_urls])
    return Counter(user_list)

# %%
user_info = scrape_user_info('https://www.trailforks.com/trails/tiger-woods-31628/')
# Out:
# /Users/forest.polchow/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/forest.polchow/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
user_info
# Out:
# Counter({'Inkhes': 32,
#          'philipmcm': 29,
#          'Speedo2fly': 21,
#          'TobyFincher': 68,
#          'AUTGERZ': 51,
#          'wpm1414': 13,
#          'LivingLikeLarry': 1,
#          'Fuelex739': 15,
#          'bigredone': 1,
#          'AD3984': 2,
#          'Tgengram': 2,
#          'sips': 1,
#          'Noah-The-Fish': 1,
#          'blindstuff': 2,
#          'oldguybob': 3,
#          'Dancecomp28': 1,
#          'ricmiami': 1,
#          'Ech0Nasty': 2,
#          'jekejaqua': 1,
#          'lohmejd': 1,
#          'RealFReEK': 1,
#          'raspy': 2,
#          'Jared13': 1,
#          'chadedwards': 7,
#          'Jcarter0127': 1,
#          'blinderman129': 1,
#          'S1ngletr4ckM1nd': 1,
#          'twomilemark': 1,
#          'willied': 5,
#          'cbarwig': 1,
#          'jtr0012': 1,
#          'scusic': 1,
#          'hbird8': 14,
#          'Dmorris360': 1,
#          'StephenHayes': 1,
#          'jmandy772': 4,
# ...

# %%
def trail_info_maker(trail_url):
    """ type_info : either '' for basic trail, 'stats/ for' """
    trail_info_dict = {}
    two_urls = [trail_url,trail_url+'stats/']
    for url in two_urls:
        r = requests.get(url)
        soup = BeautifulSoup(r.content)
        
        if 'stats' in url:
            trail_info = soup.find('ul',{'id':'trailstats_display'})
        else:
            trail_info = soup.find('ul',{'id':'traildetails_display'})
            trail_info_dict['latlng'] = find_gps_coords(soup)
            trail_info_dict['description'] = find_description(soup)
            trail_info_dict['logs'] = scrape_user_info(url)
        box = trail_info.findChildren('li')
        for item in box:
            term = item.find(class_='term').text.strip()
            definition = item.find(class_='definition').text.strip()
            trail_info_dict[term]=definition
    
    return trail_info_dict

# %%
def trail_info_maker(trail_url):
    """ type_info : either '' for basic trail, 'stats/ for' """
    trail_info_dict = {}
    soup = make_soup(trail_url)
    
    trail_info_dict['latlng'] = find_gps_coords(soup)
    trail_info_dict['description'] = find_description(soup)
    trail_info_dict['logs'] = scrape_user_info(url)
    trail_info = soup.find('ul',{'id':'traildetails_display'})
    trail_details = extract_trail_details_stats(trail_info)
    trail_stats_page = get_trails_stats_box(trail_url)
    trail_statistics = extract_trail_details_stats(trail_stats_page)
    trail_info_dict.update(trail_details)
    trail_info_dict.update(trail_statistics)
    return trail_info_dict

# %%
trail_info_maker('https://www.trailforks.com/trails/valentine-loop/')
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en">
# <head>
# <title>Valentine Loop Mountain Bike Trail - Alexandria, LA</title>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="Trail travels along the full north shore of Valentine Lake and then breaks away to the north to make a complete 3.4 mile loop through a diverse..." name="description"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@trailforks" name="twitter:site"/>
# <meta content="Valentine Loop Trail at Kincaid Recreation Area" name="twitter:title"/>
# <meta content="Trail travels along the full north shore of Valentine Lake and then breaks away to the north to make a complete 3.4 mile loop through a diverse variety of ecosystems. Through..." name="twitter:description"/>
# <meta content="https://ep1.pinkbike.org/trailstaticmap/120000/120606_0_280x150.png" name="twitter:image"/>
# ...

# %%
def make_soup(url):
    r = requests.get(url)
    return BeautifulSoup(r.content)

def get_trail_stats_box(url):
    stats_url = url + 'stats/'
    r = requests.get(url)
    soup = BeautifulSoup(r.content)
    trail_stats = soup.find('ul',{'id':'trailstats_display'})
    return trail_stats

def extract_trail_details_stats(trail_stats):
    trail_details = {}
    list_items = trail_stats.findChildren('li')
    for item in list_items:
        term = item.find(class_='term').text.strip()
        definition = item.find(class_='definition').text.strip()
        trail_details[term]=definition
    return trail_details

# %%
def simplified_trail_info_maker(trail_url):
    """ type_info : either '' for basic trail, 'stats/ for' """
    trail_info_dict = {}
    r = requests.get(trail_url)
    soup = BeautifulSoup(r.content)
    ids = ['trailstats_display','traildetails_display']
    for i in ids:
        trail_info = soup.find('ul',{'id':i})
        box = trail_info.findChildren('li')
        for item in box:
            term = item.find(class_='term').text.strip()
            definition = item.find(class_='definition').text.strip()
            trail_info_dict[term]=definition
    return trail_info_dict

# %%
trail_info = trail_info_maker('https://www.trailforks.com/trails/tiger-woods-31628/')
# Out:
# /Users/forest.polchow/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/forest.polchow/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))

# %%
trail_info
# Out:
# {'latlng': '(32.554430, -85.466690)',
#  'description': 'Tiger Woods  Trail makes a One Mile Loop from the end of  High Gravity.  Look for some neat rock options to the side or stay in the main trail and enjoy the flow!  Once you start climbing back up from the creek, look for the Chain Bridge, a very unique feature built on a natural boulder outcropping.  After topping out the climb and passing the entrance to The  Forbidden Zone on your right, rip down the  Tiger Woods Berms.  After the last big table top, you can veer left into  Tiger Woods Extension, or stay on the  Tiger Woods trail and finish out the loop by going right and up the Jeep Road to where you started.',
#  'logs': Counter({'Inkhes': 32,
#           'philipmcm': 29,
#           'Speedo2fly': 21,
#           'TobyFincher': 68,
#           'AUTGERZ': 51,
#           'wpm1414': 13,
#           'LivingLikeLarry': 1,
#           'Fuelex739': 15,
#           'bigredone': 1,
#           'AD3984': 2,
# ...

# %%
def find_gps_coords(soup):
    print(soup.find('div',class_='margin-bottom-15'))
    return soup.find('div',class_='margin-bottom-15').findAll('span')[1].text
def find_description(soup):
    return soup.find('p',{'id':'trail_description'}).text

# %%
trail_info2 = simplified_trail_info_maker('https://www.trailforks.com/trails/tiger-woods-31628/')
# Out:
# /Users/forest.polchow/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/forest.polchow/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-158-2d1aea0608f2> in <module>()
# ----> 1 trail_info2 = simplified_trail_info_maker('https://www.trailforks.com/trails/tiger-woods-31628/')
#
# ...

# %%
trail_info
# Out:
# {'latlng': '(32.554430, -85.466690)',
#  'Riding area': 'Chewacla State Park\n\n                    Auburn, Alabama',
#  'Difficulty rating': 'Blue  rate',
#  'Trail type': 'Singletrack',
#  'Bike type': 'AM, XC, Fat',
#  'Trail Usage': 'Biking Primary',
#  'Direction': 'Downhill Primary',
#  'Physical rating': 'Moderate',
#  'eBike Allowed': 'No',
#  'TTFs on trail': 'Drop, Jump, Rock Face, Roller Coaster',
#  'Global Ranking': '#2188',
#  'Distance': '1 miles',
#  'Altitude change': '-24 ft',
#  'Altitude min': '515 ft',
#  'Altitude max': '617 ft',
#  'Altitude start': '554 ft',
#  'Altitude end': '530 ft',
#  'Grade': '-0.39%',
#  'Grade max': '-19.332%',
#  'Grade min': '32.538%',
#  'Vertical climb': '209 ft',
#  'Vertical descent': '-233 ft',
#  'Distance climb': '3,331 ft',
#  'Distance descent': '2,375 ft',
#  'Distance flat': '514 ft',
#  'Avg time': '00:16:32',
#  'Avg reverse time': '00:01:22'}

# %%
r = requests.get('https://www.trailforks.com/trails/tiger-woods-31628/')
soup = BeautifulSoup(r.content)
soup.find('ul',{'id':'traildetails_display'})
# Out:
# /Users/forest.polchow/anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /Users/forest.polchow/anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# <ul class="nostyle box1 box2col padded5" id="traildetails_display">
# <li class="clearfix">
# <div class="term">Riding area</div>
# <div class="definition">
# <a class="underline" href="https://www.trailforks.com/region/chewacla-state-park/">Chewacla State Park</a>
# <br/>
# ...

# %%
from sklearn.svm import SVC

# %%
SVC()
